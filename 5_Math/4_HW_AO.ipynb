# %% [markdown]
# # Домашнее задание "Продвинутая оптимизация".

# %% [markdown]
# ### Задание

# %% [markdown]
# При фиксированном `seed=42` поэкспериментируйте с параметрами алгоритма [differential_evolution](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.differential_evolution.html): strategy, popsize, mutation.
#
# Постройте графики количества итераций (`nit`) оптимизации [функции ackley](https://en.wikipedia.org/wiki/Ackley_function) от значения параметра.
#
# Подробнее о результате выдачи [тут](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.OptimizeResult.html).

# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]

result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 90
#     nfev: 2793

# %% [markdown]
# **Strategy**

# %%
### YOUR CODE HERE
result_strategy_1 = differential_evolution(ackley, bounds, seed = 42, strategy='best1exp', tol=0.1)
result_strategy_1
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 96
#     nfev: 2973

# %%
result_strategy_2 = differential_evolution(ackley, bounds, seed = 42, strategy='currenttobest1bin', tol=0.1)
result_strategy_2
# Out:
#  message: Maximum number of iterations has been exceeded.
#  success: False
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 1000
#     nfev: 30093

# %%
result_strategy_3 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', tol=0.1)
result_strategy_3
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 90
#     nfev: 2793

# %%
result_strategy_4 = differential_evolution(ackley, bounds, seed = 42, strategy='rand1exp', tol=0.1)
result_strategy_4
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 166
#     nfev: 5073

# %%
result_strategy_5 = differential_evolution(ackley, bounds, seed = 42, strategy='randtobest1exp', tol=0.1)
result_strategy_5
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 100
#     nfev: 3093

# %%
x = ['best1exp', 'currenttobest1bin', 'best1bin', 'rand1exp', 'randtobest1exp']
y = [result_strategy_1['nit'], result_strategy_2['nit'], result_strategy_3['nit'], result_strategy_4['nit'], result_strategy_5['nit']]
plt.plot(x, y, marker='s', markersize=7)
plt.xlabel('Значение параметра "strategy"')
plt.ylabel('Количество итераций')
plt.show()

# %% [markdown]
# **Popsize**

# %%
result_popsize_1 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', popsize=10, tol=0.1)
result_popsize_1
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 97
#     nfev: 2023

# %%
result_popsize_2 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', popsize=100, tol=0.1)
result_popsize_2
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 101
#     nfev: 20463

# %%
result_popsize_3 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', popsize=200, tol=0.1)
result_popsize_3
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 91
#     nfev: 36863

# %%
result_popsize_4 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', popsize=350, tol=0.1)
result_popsize_4
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 94
#     nfev: 66563

# %%
result_popsize_5 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', popsize=500, tol=0.1)
result_popsize_5
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 97
#     nfev: 98063

# %%
x = ['10', '100', '200', '350', '500']
y = [result_popsize_1['nit'], result_popsize_2['nit'], result_popsize_3['nit'], result_popsize_4['nit'], result_popsize_5['nit']]
plt.bar(x, y)
plt.xlabel('Значение параметра "popsize"')
plt.ylabel('Количество итераций')
plt.ylim(85,105)
plt.show()

# %% [markdown]
# **Mutation**

# %%
result_mutation_1 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', mutation=0.1, tol=0.1)
result_mutation_1
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 3.57445187725768
#        x: [ 9.685e-01  9.685e-01]
#      nit: 3
#     nfev: 135
#      jac: [ 0.000e+00  3.553e-07]

# %%
result_mutation_2 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', mutation=0.5, tol=0.1)
result_mutation_2
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 57
#     nfev: 1803

# %%
result_mutation_3 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', mutation=1.0, tol=0.1)
result_mutation_3
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 1.283417816466681e-13
#        x: [ 4.441e-14  4.441e-15]
#      nit: 136
#     nfev: 4173

# %%
result_mutation_4 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', mutation=1.4, tol=0.1)
result_mutation_4
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 269
#     nfev: 8163

# %%
result_mutation_5 = differential_evolution(ackley, bounds, seed = 42, strategy='best1bin', mutation=1.9, tol=0.1)
result_mutation_5
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 1.8802102097481566e-09
#        x: [-6.648e-10 -2.236e-12]
#      nit: 242
#     nfev: 7353

# %%
x = ['0.1', '0.5', '1.0', '1.4', '1.9']
y = [result_mutation_1['nit'], result_mutation_2['nit'], result_mutation_3['nit'], result_mutation_4['nit'], result_mutation_5['nit']]
plt.bar(x, y)
plt.xlabel('Значение параметра "mutation"')
plt.ylabel('Количество итераций')
#plt.ylim(85,105)
plt.show()

# %% [markdown]
# ### Дополнительное задание

# %% [markdown]
# Поэкспериментируйте с параметрами и оптимизацией через [minimize](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html):

# %%
from scipy.optimize import minimize

x0 = [0,0]

result_m = minimize(ackley, x0,  method='Nelder-Mead')
result_m
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 4.440892098500626e-16
#              x: [ 0.000e+00  0.000e+00]
#            nit: 8
#           nfev: 17
#  final_simplex: (array([[ 0.000e+00,  0.000e+00],
#                        [-1.607e-05, -8.453e-06],
#                        [-1.404e-06, -3.113e-05]]), array([ 4.441e-16,  5.136e-05,  8.816e-05]))

# %%
### YOUR CODE HERE
result_m = minimize(ackley, x0,  method='Nelder-Mead', options={'xatol': 1e-8, 'disp':True})
result_m
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 63
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 4.440892098500626e-16
#              x: [ 0.000e+00  0.000e+00]
#            nit: 31
#           nfev: 63
#  final_simplex: (array([[ 0.000e+00,  0.000e+00],
#                        [ 7.291e-09, -1.651e-09],
#                        [ 2.511e-09, -8.552e-09]]), array([ 4.441e-16,  2.114e-08,  2.521e-08]))

# %%
result_m = minimize(ackley, x0,  method='BFGS')
result_m
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 4.440892098500626e-16
#         x: [ 0.000e+00  0.000e+00]
#       nit: 0
#       jac: [ 2.828e+00  2.828e+00]
#  hess_inv: [[1 0]
#             [0 1]]
#      nfev: 165
#      njev: 51

# %%
result_m = minimize(ackley, x0,  method='L-BFGS-B')
result_m
# Out:
#   message: ABNORMAL_TERMINATION_IN_LNSRCH
#   success: False
#    status: 2
#       fun: 4.440892098500626e-16
#         x: [ 0.000e+00  0.000e+00]
#       nit: 0
#       jac: [ 2.828e+00  2.828e+00]
#      nfev: 63
#      njev: 21
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %%
result_m = minimize(ackley, x0,  method='Powell')
result_m
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4.440892098500626e-16
#        x: [ 0.000e+00  0.000e+00]
#      nit: 1
#    direc: [[ 1.000e+00  0.000e+00]
#            [ 0.000e+00  1.000e+00]]
#     nfev: 61

# %% [markdown]
# Вы также можете поэкспериментировать с [другими методами оптимизации](https://habr.com/ru/company/prequel/blog/568496/), но это не обязательно для зачета.
